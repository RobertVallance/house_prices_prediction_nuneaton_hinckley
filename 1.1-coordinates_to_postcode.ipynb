# %% [markdown]
# # Coordinates to Postcode
# Convert the longitude and latitude in the Zoopla data to postcodes. Unfortunately we don't have the postcode or house number in the Zoopla data. So we will infer this from the property longitude and latitude. Datasets of all postcodes for a given area, including their mean latitude and longitude are available from Source: https://www.doogal.co.uk/AdministrativeAreas. We will then use the inferred property postcode to join other data (e.g. deprivation data, flood risk data, EPC data (averages for that postcode and road) and government historic property prices (averages for that postcode, house type, year, etc).

# %%
from collections import Counter
import os
import numpy as np
import pandas as pd
import re
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ### Read in mapping files

# %%
AREA = 'Hinckley'
DATA_FOLDER = os.path.join('data', 'raw')
SAVE_FOLDER = os.path.join('data', 'processed')

# %%
if AREA == 'Nuneaton':
    mapping_df_filename = 'Nuneaton and Bedworth postcodes.csv'
    zoopla_df_filename = 'zoopla_properties_nuneaton.csv'
elif AREA == 'Hinckley':
    mapping_df_filename = 'Hinckley and Bosworth postcodes.csv'
    zoopla_df_filename = 'zoopla_properties_hinckley.csv'
    
mapping_df = pd.read_csv(os.path.join(DATA_FOLDER, mapping_df_filename))
zoopla_df = pd.read_csv(os.path.join(DATA_FOLDER, zoopla_df_filename))

# %%
print(mapping_df.shape)
display(mapping_df.head())
# Out:
# (3515, 17)
#    Postcode In Use?   Latitude  Longitude  Easting  Northing  Grid Ref  \
# 0  CV10 0RY     Yes  52.559033  -1.482983   435148    295814  SP351958
# 1  CV10 0SB     Yes  52.562270  -1.487188   434860    296172  SP348961
# 2  CV10 0TT     Yes  52.554782  -1.461007   436641    295352  SP366953
# 3  CV10 0TU     Yes  52.553685  -1.464958   436374    295228  SP363952
# 4  CV10 0TZ     Yes  52.549290  -1.449379   437434    294747  SP374947
#
#                                  Ward              Parish  Introduced  \
# 0  Twycross and Witherley with Sheepy           Witherley  1980-01-01
# 1  Twycross and Witherley with Sheepy           Witherley  1980-01-01
# 2                              Ambien  Higham on the Hill  1980-01-01
# 3                              Ambien  Higham on the Hill  1998-12-01
# 4                              Ambien  Higham on the Hill  1980-01-01
#
#   Terminated  Altitude  Country Last Updated  \
# 0        NaN        81  England   2022-11-25
# 1        NaN        83  England   2022-11-25
# 2        NaN        96  England   2022-11-25
# 3        NaN        90  England   2022-11-25
# 4        NaN       104  England   2022-11-25
#
#                                              Quality  LSOA Code  \
# 0  Within the building of the matched address clo...  E01025881
# 1  Within the building of the matched address clo...  E01025881
# 2  Within the building of the matched address clo...  E01025818
# 3  Within the building of the matched address clo...  E01025818
# 4  Within the building of the matched address clo...  E01025818
#
#                     LSOA Name
# 0  Hinckley and Bosworth 008D
# 1  Hinckley and Bosworth 008D
# 2  Hinckley and Bosworth 008B
# 3  Hinckley and Bosworth 008B
# 4  Hinckley and Bosworth 008B

# %% [markdown]
# ### Map latitude and longitude to postcode
#
# Create function that takes the longitude and latitude from the Zoopla data and find the closest one in the mapping data, returning the corresponding postcode in the mapping file.

# %%
def get_closest_postcode(latitude, longitude, map_df):
    
    """
    Find the nearest longitude and latitude in mapping file and get the postcode.
    This uses the Euclidean (rather than Haversine) distance, since the distances will be small
    such that the Earth's curvature need not be considered.
    An alternative could be to use geopy.reverse() to convert coordinates to postcodes.
    
    Parameters
    ----------
    - latitude (float): latitude of the Zoopla property
    - longitude (float): longitude of the Zoopla property
    - map_df (pandas.DataFrame): dataframe that maps coordinates to postcodes
    
    Returns
    -------
    - postcode (string): postcode closely mapping the Zoopla property
    """
    
    # squared euclidean distance between Zoopla property and each mapping dataset postcode mean
    # this uses array broadcasting in numpy
    sq_distances = (np.array(latitude) - np.array(map_df['Latitude']))**2 + \
        (np.array(longitude) - np.array(map_df['Longitude']))**2 
    
    min_sq_distance_row = np.argmin(sq_distances)
    
    return map_df.iloc[min_sq_distance_row]['Postcode']

# %%
zoopla_df['postcode_test_1'] = zoopla_df[['latitude', 'longitude']].apply(lambda x: get_closest_postcode(x[0], x[1], mapping_df), axis=1)

# %%
zoopla_df[['latitude', 'longitude', 'postcode_test_1']].head(10)
# Out:
#     latitude  longitude postcode_test_1
# 0  52.538830  -1.396291        LE10 0NS
# 1  52.548298  -1.353169        LE10 1ND
# 2  52.552856  -1.375555        LE10 0EQ
# 3  52.534348  -1.392864        LE10 0LW
# 4  52.546017  -1.386440        LE10 0XB
# 5  52.547695  -1.388362        LE10 0TN
# 6  52.545380  -1.372886        LE10 1RP
# 7  52.537320  -1.375827        LE10 0PJ
# 8  52.542767  -1.394461        LE10 0XW
# 9  52.533012  -1.397817        LE10 0YL

# %% [markdown]
# This works OK but sometimes we get an adjacent postcode to the one we want. Instead, let's try combining it with the road name by loading the EPC data which has postcodes and names, and joining to the Zoopla data on the street name.

# %% [markdown]
# ### Try getting postcode from road name using EPC data
# Data available from https://epc.opendatacommunities.org/domestic/search

# %%
def get_most_common_postcode(postcode_list):
    
    """
    Return the most frequent value in a list
    """
    
    if not postcode_list:
        return None
    else:
        postcode_counter = Counter(postcode_list)
        return postcode_counter.most_common()[0][0]

# %%
def get_street_name(address_1, address_2):
    
    """
    Get street name from first two street address fields
    """
    
    street_and_road = re.compile(r'^\d,\s+')
    
    # if street name starts with a number (maybe followed by comma) and a space, likely next part is street name
    if street_and_road.match(address_1):
        street = re.split(street_and_road, address_1)[1].lower()
        
    # otherwise choose the second part of the address as the street name
    else:
        street = str(address_2).lower()
        
    return street

# %%
def get_postcode(latitude, longitude, street_name, method='closest'):
    
    """
    Convert longitude and latitude into a post code, using the street name to narrow 
    the possible post codes down. Two methods possible, discussed below.
    
    Parameters
    ----------
    - latitude (float): latitude of the Zoopla property
    - longitude (float): longitude of the Zoopla property
    - street_name (string): the street name for the Zoopla property
    - method (string) default='closest': algorithm for choosing the postcode
       - closest: uses Euclidean distance to calculate the
         nearest longitude and latitude in the mapping file to the Zoopla property and gets the postcode
       - frequency: gets the most common postcode for the property's street name
    
    Returns
    -------
    - postcode (string): postcode closely mapping the Zoopla property
    """
    
    # get all possible postcodes for the street name
    possible_postcodes = list(epc_df[epc_df['Street'].str.lower()==street_name.lower()]['POSTCODE'])
    
    if method == 'frequency':
        
        final_postcode = get_most_common_postcode(possible_postcodes)
        
        # if there is no most common postcode in the EPC data, use the 'closest' algorithm instead
        if not final_postcode:
            method = 'closest'
        
    if method == 'closest':
        
        possible_postcodes = set(possible_postcodes)
        
        # if set is empty, try all possible postcodes and find nearest one
        if not possible_postcodes:
            final_postcode = get_closest_postcode(latitude, longitude, mapping_df)
        
        # if set is filled, limit search to the postcodes in the set
        else:

            # get mapping dataframe of just the postcodes in the above set
            mapping_df_temp = mapping_df[mapping_df['Postcode'].isin(possible_postcodes)]
            
            # where mapping dataframe filled, otherwise, choose the postcode from the set 
            # whose location is closest to the property longitude and latitude
            if not mapping_df_temp.empty:
                final_postcode = get_closest_postcode(latitude, longitude, mapping_df_temp)
            
            # if the postcodes are not found in the mapping file (likely due to
            # that postcode falling outside the geo boundary of the mapping file),
            # set the postcode to the first element in the possible_postcodes set 
            else:
                final_postcode = sorted(possible_postcodes)[0]
            

    return final_postcode

# %%
if AREA == 'Nuneaton':
    epc_filename = 'epcs_nuneaton.csv'
elif AREA == 'Hinckley':
    epc_filename = 'epcs_hinckley.csv'

epc_df = pd.read_csv(os.path.join(DATA_FOLDER, epc_filename), dtype=str)

# %%
print(epc_df.shape)
display(epc_df.head())
# Out:
# (42663, 92)
#                                              LMK_KEY            ADDRESS1  \
# 0  188e4e7604368b7386e5ff93771a037ccfb150c2861096...     5 Brockey Close
# 1                  849605851212012102416531797929305         2, Nob Hill
# 2                 1062831709962013121817485087588537     21, Barrie Road
# 3                  641449911152012091816382695920980   69, Hinckley Road
# 4                  496648659922010061416010176908480  8, Pickering Place
#
#                 ADDRESS2 ADDRESS3  POSTCODE BUILDING_REFERENCE_NUMBER  \
# 0                Barwell      NaN   LE9 8BG               10003465551
# 1  Norton juxta Twycross      NaN   CV9 3QE                3560172078
# 2                    NaN      NaN  LE10 0QU                3806087178
# 3           Earl Shilton      NaN   LE9 7LH                9039157868
# 4                Burbage      NaN  LE10 2FJ                8785576768
#
#   CURRENT_ENERGY_RATING POTENTIAL_ENERGY_RATING CURRENT_ENERGY_EFFICIENCY  \
# 0                     D                       B                        68
# 1                     D                       C                        67
# 2                     E                       B                        53
# 3                     D                       C                        64
# 4                     B                       B                        83
#
#   POTENTIAL_ENERGY_EFFICIENCY PROPERTY_TYPE   BUILT_FORM INSPECTION_DATE  \
# 0                          87      Bungalow     Detached      2022-10-04
# 1                          80         House     Detached      2012-10-19
# 2                          82         House  End-Terrace      2013-12-18
# 3                          79      Bungalow     Detached      2012-09-18
# 4                          85          Flat     NO DATA!      2010-06-10
#
#   LOCAL_AUTHORITY CONSTITUENCY          COUNTY LODGEMENT_DATE  \
# 0       E07000132    E14000583  Leicestershire     2022-10-10
# 1       E07000132    E14000583  Leicestershire     2012-10-24
# 2       E07000132    E14000583  Leicestershire     2013-12-18
# 3       E07000132    E14000583  Leicestershire     2012-09-18
# 4       E07000132    E14000583  Leicestershire     2010-06-14
#
#             TRANSACTION_TYPE ENVIRONMENT_IMPACT_CURRENT  \
# 0     Stock condition survey                         67
# 1              marketed sale                         60
# 2  assessment for green deal                         49
# 3              marketed sale                         59
# 4               new dwelling                         83
#
#   ENVIRONMENT_IMPACT_POTENTIAL ENERGY_CONSUMPTION_CURRENT  \
# 0                           87                        270
# 1                           75                        156
# 2                           81                        303
# 3                           76                        207
# 4                           84                        134
#
#   ENERGY_CONSUMPTION_POTENTIAL CO2_EMISSIONS_CURRENT  \
# 0                          102                   2.2
# 1                           94                   8.4
# 2                          103                   4.9
# 3                          118                   5.1
# 4                          127                   1.4
#
#   CO2_EMISS_CURR_PER_FLOOR_AREA CO2_EMISSIONS_POTENTIAL LIGHTING_COST_CURRENT  \
# 0                            48                     0.9                    44
# 1                            34                     5.2                   112
# 2                            58                     1.7                    80
# 3                            40                     3.0                   111
# 4                            22                     1.3                    57
#
#   LIGHTING_COST_POTENTIAL HEATING_COST_CURRENT HEATING_COST_POTENTIAL  \
# 0                      44                  418                    370
# 1                     112                 1463                   1067
# 2                      49                  892                    519
# 3                      62                  817                    679
# 4                      34                  212                    215
#
#   HOT_WATER_COST_CURRENT HOT_WATER_COST_POTENTIAL TOTAL_FLOOR_AREA  \
# 0                     59                       39               47
# 1                    172                      105              243
# 2                     82                       58               84
# 3                    110                       75              128
# 4                     85                       85               61
#
#      ENERGY_TARIFF MAINS_GAS_FLAG FLOOR_LEVEL FLAT_TOP_STOREY  \
# 0           Single              Y         NaN             NaN
# 1           Single              N     NODATA!             NaN
# 2           Single              Y     NODATA!             NaN
# 3           Single              Y     NODATA!             NaN
# 4  standard tariff            NaN   mid floor             NaN
#
#   FLAT_STOREY_COUNT MAIN_HEATING_CONTROLS MULTI_GLAZE_PROPORTION  \
# 0               NaN                   NaN                    100
# 1               NaN                  2106                     85
# 2               NaN                  2107                    100
# 3               NaN                  2106                    100
# 4               NaN                   NaN                    NaN
#
#                                      GLAZED_TYPE GLAZED_AREA EXTENSION_COUNT  \
# 0           double glazing installed before 2002      Normal               0
# 1           double glazing, unknown install date      Normal               1
# 2           double glazing, unknown install date      Normal               1
# 3  double glazing installed during or after 2002      Normal               1
# 4                                       NO DATA!    NO DATA!             NaN
#
#   NUMBER_HABITABLE_ROOMS NUMBER_HEATED_ROOMS LOW_ENERGY_LIGHTING  \
# 0                      3                   3                 100
# 1                      8                   8                  73
# 2                      5                   5                  36
# 3                      5                   5                  20
# 4                    NaN                 NaN                   3
#
#   NUMBER_OPEN_FIREPLACES HOTWATER_DESCRIPTION HOT_WATER_ENERGY_EFF  \
# 0                      0     From main system                 Good
# 1                      0     From main system                 Good
# 2                      0     From main system                 Good
# 3                      1     From main system                 Good
# 4                    NaN     From main system                 Good
#
#   HOT_WATER_ENV_EFF                   FLOOR_DESCRIPTION FLOOR_ENERGY_EFF  \
# 0              Good      Solid, no insulation (assumed)              NaN
# 1           Average      Solid, no insulation (assumed)              NaN
# 2              Good  Suspended, no insulation (assumed)              NaN
# 3              Good      Solid, no insulation (assumed)              NaN
# 4              Good              (other premises below)              NaN
#
#   FLOOR_ENV_EFF    WINDOWS_DESCRIPTION WINDOWS_ENERGY_EFF WINDOWS_ENV_EFF  \
# 0           NaN    Fully double glazed            Average         Average
# 1           NaN  Mostly double glazing               Poor            Poor
# 2           NaN    Fully double glazed            Average         Average
# 3           NaN    Fully double glazed               Good            Good
# 4           NaN    Fully double glazed               Good            Good
#
#                                    WALLS_DESCRIPTION WALLS_ENERGY_EFF  \
# 0         Cavity wall, as built, insulated (assumed)             Good
# 1  Cavity wall, as built, partial insulation (ass...          Average
# 2     Solid brick, as built, no insulation (assumed)        Very Poor
# 3                         Cavity wall, filled cavity             Good
# 4           Average thermal transmittance 0.45 W/m?K             Good
#
#   WALLS_ENV_EFF   SECONDHEAT_DESCRIPTION SHEATING_ENERGY_EFF SHEATING_ENV_EFF  \
# 0          Good  Room heaters, mains gas                 NaN              NaN
# 1       Average  Room heaters, wood logs                 NaN              NaN
# 2     Very Poor  Room heaters, mains gas                 NaN              NaN
# 3          Good  Room heaters, mains gas                 NaN              NaN
# 4          Good                     None                 NaN              NaN
#
#                   ROOF_DESCRIPTION ROOF_ENERGY_EFF ROOF_ENV_EFF  \
# 0  Pitched, 270 mm loft insulation            Good         Good
# 1  Pitched, 150 mm loft insulation            Good         Good
# 2  Pitched, 200 mm loft insulation            Good         Good
# 3  Pitched, 100 mm loft insulation         Average      Average
# 4           (other premises above)             NaN          NaN
#
#               MAINHEAT_DESCRIPTION MAINHEAT_ENERGY_EFF MAINHEAT_ENV_EFF  \
# 0  Boiler and radiators, mains gas                Good             Good
# 1        Boiler and radiators, oil                Good             Good
# 2  Boiler and radiators, mains gas                Good             Good
# 3  Boiler and radiators, mains gas                Good             Good
# 4  Boiler and radiators, mains gas                Good             Good
#
#                MAINHEATCONT_DESCRIPTION MAINHEATC_ENERGY_EFF  \
# 0  Programmer, room thermostat and TRVs                 Good
# 1  Programmer, room thermostat and TRVs                 Good
# 2           Programmer, TRVs and bypass              Average
# 3  Programmer, room thermostat and TRVs                 Good
# 4  Programmer, room thermostat and TRVs              Average
#
#   MAINHEATC_ENV_EFF                         LIGHTING_DESCRIPTION  \
# 0              Good     Low energy lighting in all fixed outlets
# 1              Good  Low energy lighting in 73% of fixed outlets
# 2           Average  Low energy lighting in 36% of fixed outlets
# 3              Good  Low energy lighting in 20% of fixed outlets
# 4           Average  Low energy lighting in 33% of fixed outlets
#
#   LIGHTING_ENERGY_EFF LIGHTING_ENV_EFF  \
# 0           Very Good        Very Good
# 1           Very Good        Very Good
# 2             Average          Average
# 3                Poor             Poor
# 4             Average          Average
#
#                                            MAIN_FUEL WIND_TURBINE_COUNT  \
# 0                          mains gas (not community)                  0
# 1                                oil (not community)                  0
# 2                          mains gas (not community)                  0
# 3                          mains gas (not community)                  0
# 4  mains gas - this is for backwards compatibilit...                  0
#
#   HEAT_LOSS_CORRIDOR UNHEATED_CORRIDOR_LENGTH FLOOR_HEIGHT PHOTO_SUPPLY  \
# 0                NaN                      NaN          2.3          0.0
# 1           NO DATA!                      NaN          NaN          0.0
# 2           NO DATA!                      NaN          NaN          0.0
# 3           NO DATA!                      NaN          NaN          0.0
# 4           NO DATA!                      NaN         2.45          NaN
#
#   SOLAR_WATER_HEATING_FLAG MECHANICAL_VENTILATION  \
# 0                        N                natural
# 1                      NaN                natural
# 2                      NaN                natural
# 3                      NaN                natural
# 4                      NaN               NO DATA!
#
#                               ADDRESS  LOCAL_AUTHORITY_LABEL  \
# 0            5 Brockey Close, Barwell  Hinckley and Bosworth
# 1  2, Nob Hill, Norton juxta Twycross  Hinckley and Bosworth
# 2                     21, Barrie Road  Hinckley and Bosworth
# 3     69, Hinckley Road, Earl Shilton  Hinckley and Bosworth
# 4         8, Pickering Place, Burbage  Hinckley and Bosworth
#
#   CONSTITUENCY_LABEL    POSTTOWN         CONSTRUCTION_AGE_BAND  \
# 0           Bosworth   LEICESTER  England and Wales: 1983-1990
# 1           Bosworth  ATHERSTONE  England and Wales: 1976-1982
# 2           Bosworth    HINCKLEY  England and Wales: 1930-1949
# 3           Bosworth   LEICESTER  England and Wales: 1930-1949
# 4           Bosworth    HINCKLEY                      NO DATA!
#
#     LODGEMENT_DATETIME           TENURE FIXED_LIGHTING_OUTLETS_COUNT  \
# 0  2022-10-10 19:12:48  Rented (social)                            6
# 1  2012-10-24 16:53:17   owner-occupied                           26
# 2  2013-12-18 17:48:50   owner-occupied                           11
# 3  2012-09-18 16:38:26   owner-occupied                           15
# 4  2010-06-14 16:01:01              NaN                            9
#
#   LOW_ENERGY_FIXED_LIGHT_COUNT          UPRN      UPRN_SOURCE
# 0                          NaN  100032074592  Energy Assessor
# 1                           19  100030495131  Address Matched
# 2                            4  100030497070  Address Matched
# 3                            3  100030519581  Address Matched
# 4                            3   10090026218  Address Matched

# %%
# get street name from addresses
epc_df['Street'] = epc_df[['ADDRESS1', 'ADDRESS2']].apply(lambda x: get_street_name(x[0], x[1]), axis=1)

# %%
# try both 'closest' and 'frequency' method to get postcode
zoopla_df['postcode_test_2'] = zoopla_df[['latitude', 'longitude', 'street_name']].apply(lambda x: get_postcode(x[0], x[1], x[2], method='closest'), axis=1)
zoopla_df['postcode_test_3'] = zoopla_df[['latitude', 'longitude', 'street_name']].apply(lambda x: get_postcode(x[0], x[1], x[2], method='frequency'), axis=1)

# %%
zoopla_df[['latitude', 'longitude', 'postcode_test_1', 'postcode_test_2', 'postcode_test_3']].head(30)
# Out:
#      latitude  longitude postcode_test_1 postcode_test_2 postcode_test_3
# 0   52.538830  -1.396291        LE10 0NS        LE10 0NS        LE10 0NS
# 1   52.548298  -1.353169        LE10 1ND        LE10 1ND        LE10 1ND
# 2   52.552856  -1.375555        LE10 0EQ        LE10 0RH        LE10 0RH
# 3   52.534348  -1.392864        LE10 0LW        LE10 0LW        LE10 0LR
# 4   52.546017  -1.386440        LE10 0XB        LE10 0XB        LE10 0XB
# 5   52.547695  -1.388362        LE10 0TN        LE10 0TN        LE10 0TN
# 6   52.545380  -1.372886        LE10 1RP        LE10 1RP        LE10 1RP
# 7   52.537320  -1.375827        LE10 0PJ        LE10 0PJ        LE10 0PJ
# 8   52.542767  -1.394461        LE10 0XW        LE10 0XW        LE10 0XW
# 9   52.533012  -1.397817        LE10 0YL        LE10 0YL        LE10 0YJ
# 10  52.556470  -1.369090        LE10 3DH        LE10 1UR        LE10 1UR
# 11  52.550716  -1.381520        LE10 0DG        LE10 0DG        LE10 0DQ
# 12  52.552860  -1.368882        LE10 0RD        LE10 0RD        LE10 0RF
# 13  52.552853  -1.368886        LE10 0RD        LE10 0RD        LE10 0RD
# 14  52.534680  -1.394174        LE10 0LL        LE10 0LL        LE10 0LL
# 15  52.546227  -1.395482        LE10 0WT        LE10 0BE        LE10 0BE
# 16  52.547413  -1.354690        LE10 1LA        LE10 1LA        LE10 1LA
# 17  52.549736  -1.373662        LE10 0EE        LE10 0EE        LE10 0ED
# 18  52.547110  -1.374521        LE10 0DY        LE10 0DY        LE10 0DY
# 19  52.538895  -1.366481        LE10 1AH        LE10 1AQ        LE10 1AQ
# 20  52.539740  -1.361549        LE10 1DP        LE10 1DP        LE10 1DP
# 21  52.550106  -1.350836        LE10 1FF        LE10 1FN        LE10 1FN
# 22  52.545383  -1.394853        LE10 0WT        LE10 0WT        LE10 0WT
# 23  52.536304  -1.375974        LE10 0QF        LE10 0QF        LE10 0QF
# 24  52.544376  -1.395408        LE10 0WY        LE10 0WY        LE10 0WY
# 25  52.543175  -1.376060        LE10 0AQ        LE10 0AQ        LE10 0AQ
# 26  52.533485  -1.410670        LE10 3ED        LE10 3ED        LE10 3ED
# 27  52.548350  -1.367339        LE10 1QS        LE10 1QS        LE10 1QS
# 28  52.546738  -1.393862        LE10 0WP        LE10 0WP        LE10 0WP
# 29  52.548264  -1.356881        LE10 1LH        LE10 1LH        LE10 1LH

# %% [markdown]
# From checks on Google, the 'closest' method is most accurate so will be used for this dataset

# %%
zoopla_df.drop(columns=['postcode_test_1', 'postcode_test_3'], inplace=True)
zoopla_df = zoopla_df.rename(columns={'postcode_test_2': 'postcode'})

# %% [markdown]
# ### Get the parish from the postcode

# %%
def get_parish(postcode):
    
    """
    Get the parish of the Zoopla property from the mapping dataframe (based on postcode)
    """
    
    try:
        return mapping_df[mapping_df['Postcode']==postcode].iloc[0]['Parish']
    except IndexError:
        if AREA == 'Nuneaton':
            return "Nuneaton and Bedworth, unparished area"
        elif AREA == 'Hinckley':
            return "Hinckley and Bosworth, unparished area"

# %%
zoopla_df['parish'] = zoopla_df['postcode'].apply(lambda x: get_parish(x))

# %%
zoopla_df['parish'].value_counts()
# Out:
# Hinckley and Bosworth, unparished area    279
# Burbage                                    12
# Sheepy                                      1
# Name: parish, dtype: int64

# %% [markdown]
# Maybe not such a useful feature but keep for now!

# %% [markdown]
# ### Save to csv file

# %%
zoopla_df.head()
# Out:
#                                          details_url   agent_phone  \
# 0  https://www.zoopla.co.uk/for-sale/details/6388...  01455 886081
# 1  https://www.zoopla.co.uk/for-sale/details/6387...  01455 364814
# 2  https://www.zoopla.co.uk/for-sale/details/6387...  01455 364814
# 3  https://www.zoopla.co.uk/for-sale/details/6387...  01455 364026
# 4  https://www.zoopla.co.uk/for-sale/details/6152...  01455 364871
#
#                                          description  \
# 0   Attractive extended traditional bay fronted s...
# 1   ** viewing essential ** A beautifully present...
# 2   **viewing essential ** A well appointed semi ...
# 3   An immaculately maintained tastefully decorat...
# 4  You're sure to be impressed when you enter thi...
#
#                    agent_address   latitude  longitude outcode country_code  \
# 0     98 Castle Street, Hinckley  52.538830  -1.396291    LE10           gb
# 1    112 Castle Street, Hinckley  52.548298  -1.353169    LE10           gb
# 2    112 Castle Street, Hinckley  52.552856  -1.375555    LE10           gb
# 3  28-30 New Buildings, Hinckley  52.534348  -1.392864    LE10           gb
# 4      84 Castle Steet, Hinckley  52.546017  -1.386440    LE10           gb
#
#    num_bathrooms listing_status        property_type  listing_id  num_recepts  \
# 0              1           sale  Semi-detached house    63884099            2
# 1              4           sale       Detached house    63878342            2
# 2              1           sale  Semi-detached house    63874929            2
# 3              1           sale  Semi-detached house    63871971            1
# 4              1           sale             Bungalow    61524804            1
#
#   post_town                        displayable_address  floor_plan  \
# 0  Hinckley               Langdale Road, Hinckley LE10         NaN
# 1  Hinckley            Bradgate Gardens, Hinckley LE10         NaN
# 2  Hinckley                   York Road, Hinckley LE10         NaN
# 3  Hinckley             Strathmore Road, Hinckley LE10         NaN
# 4  Hinckley  Aulton Way, Hinckley, Leicestershire LE10         NaN
#
#                                            image_url       street_name  \
# 0  https://lid.zoocdn.com/354/255/c9c518b9e9bd024...     Langdale Road
# 1  https://lid.zoocdn.com/354/255/e2c80f945cd69da...  Bradgate Gardens
# 2  https://lid.zoocdn.com/354/255/4fd00c679828a04...         York Road
# 3  https://lid.zoocdn.com/354/255/31105260d73c332...   Strathmore Road
# 4  https://lid.zoocdn.com/354/255/88ccf710c285162...        Aulton Way
#
#                                      agent_name          county  \
# 0  Scrivins & Co Estate Agents & Letting Agents  Leicestershire
# 1                                Castle Estates  Leicestershire
# 2                                Castle Estates  Leicestershire
# 3                                      Profiles  Leicestershire
# 4                          Your Move - Hinckley  Leicestershire
#
#         price_modifier first_published_date  country  last_published_date  \
# 0                  NaN  2023-02-04 11:38:12  England  2023-02-04 11:39:32
# 1          offers_over  2023-02-03 15:54:45  England  2023-02-04 09:42:14
# 2          offers_over  2023-02-03 11:20:13  England  2023-02-03 13:17:45
# 3  offers_in_region_of  2023-02-02 22:07:06  England  2023-02-02 22:07:06
# 4                  NaN  2023-02-01 18:08:21  England  2023-02-01 18:08:21
#
#       price     category  num_bedrooms  \
# 0  260000.0  Residential             3
# 1  450000.0  Residential             5
# 2  280000.0  Residential             3
# 3  260000.0  Residential             3
# 4  315000.0  Residential             3
#
#                                           agent_logo  postcode  \
# 0  https://st.zoocdn.com/zoopla_static_agent_logo...  LE10 0NS
# 1  https://st.zoocdn.com/zoopla_static_agent_logo...  LE10 1ND
# 2  https://st.zoocdn.com/zoopla_static_agent_logo...  LE10 0RH
# 3  https://st.zoocdn.com/zoopla_static_agent_logo...  LE10 0LW
# 4  https://st.zoocdn.com/zoopla_static_agent_logo...  LE10 0XB
#
#                                    parish
# 0  Hinckley and Bosworth, unparished area
# 1  Hinckley and Bosworth, unparished area
# 2  Hinckley and Bosworth, unparished area
# 3  Hinckley and Bosworth, unparished area
# 4  Hinckley and Bosworth, unparished area

# %%
try:
    os.mkdir(SAVE_FOLDER)
except OSError:
    pass

save_file = os.path.join(SAVE_FOLDER, f'zoopla_properties_with_postcode_{AREA.lower()}.csv')
    
zoopla_df.to_csv(save_file, index=False)
